# %% [markdown]
# ## Name:
# ### Hafiz Muhammad Abdullah
# ## Email:
# ### abdullah826928@gmail.com
#
# ## Project Name:
# ### Titanic

# %% [markdown]
# ## Step 1
# ### install Librarires

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 490.5 kB/s eta 0:00:19
#    -- ------------------------------------- 0.5/9.8 MB 490.5 kB/s eta 0:00:19
#    --- ------------------------------------ 0.8/9.8 MB 508.2 kB/s eta 0:00:18
#    --- ------------------------------------ 0.8/9.8 MB 508.2 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.0/9.8 MB 529.6 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.0/9.8 MB 529.6 kB/s eta 0:00:17
# ...

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 861.4 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/12.4 MB 978.6 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.4 MB 978.6 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.4 MB 911.9 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.4 MB 955.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.4 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.4 MB 1.2 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.4 MB 1.3 MB/s eta 0:00:08
# ...

# %%
#import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2
# ### Load data

# %%
#loading data
pd.read_csv("titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
