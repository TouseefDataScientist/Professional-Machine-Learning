# %% [markdown]
# ## Name:
# ### Hafiz Muhammad Abdullah
# ## Email:
# ### abdullah826928@gmail.com
#
# ## Project Name:
# ### Titanic

# %% [markdown]
# ## Step 1
# ### install Librarires

# %%
% pip install pandas

# %%
pip install numpy

# %%
#import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2
# ### Load data

# %%
#loading data
pd.read_csv("titanic.csv")
